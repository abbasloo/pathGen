# %% [markdown]
# vis:
#
# https://pypi.org/project/folium/0.1.4/
#
# https://blog.dominodatalab.com/creating-interactive-crime-maps-with-folium/
#
# networks:
#
# https://geoffboeing.com/2016/11/osmnx-python-street-networks/
#
# dataformat:
#
# http://geopandas.org/gallery/index.html

# %%
import folium


map_osm = folium.Map(location=[50.949650, 6.933180], zoom_start=20)
map_osm_stamen = folium.Map(location=[50.949650, 6.933180], tiles='Stamen Toner', zoom_start=20)
folium.Marker([50.949650, 6.933180], popup='Mt. Hood Meadows').add_to(map_osm)
display(map_osm)
display(map_osm_stamen)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
